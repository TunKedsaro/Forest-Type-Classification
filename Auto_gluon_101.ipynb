# %%
# !pip install autogluon.tabular

import numpy as np
import pandas as pd
import os
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
# Out:
# Collecting autogluon.tabular
#   Downloading autogluon.tabular-1.1.0-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.5/308.5 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.29,>=1.21 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular) (1.25.2)
# Requirement already satisfied: scipy<1.13,>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular) (1.11.4)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular) (2.0.3)
# Collecting scikit-learn<1.4.1,>=1.3.0 (from autogluon.tabular)
#   Downloading scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: networkx<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular) (3.3)
# Collecting autogluon.core==1.1.0 (from autogluon.tabular)
#   Downloading autogluon.core-1.1.0-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.5 MB/s eta 0:00:00
# Collecting autogluon.features==1.1.0 (from autogluon.tabular)
#   Downloading autogluon.features-1.1.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5,>=4.38 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.1.0->autogluon.tabular) (4.66.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.1.0->autogluon.tabular) (2.31.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.1.0->autogluon.tabular) (3.7.1)
# Collecting boto3<2,>=1.10 (from autogluon.core==1.1.0->autogluon.tabular)
#   Downloading boto3-1.34.117-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.9 MB/s eta 0:00:00
# Collecting autogluon.common==1.1.0 (from autogluon.core==1.1.0->autogluon.tabular)
#   Downloading autogluon.common-1.1.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil<6,>=5.7.3 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.tabular) (5.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.tabular) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.tabular) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.tabular) (3.5.0)
# Collecting botocore<1.35.0,>=1.34.117 (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.tabular)
#   Downloading botocore-1.34.117-py3-none-any.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 38.5 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.tabular)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.tabular)
#   Downloading s3transfer-0.10.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=2.0.0->autogluon.tabular) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->autogluon.core==1.1.0->autogluon.tabular) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->autogluon.core==1.1.0->autogluon.tabular) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->autogluon.core==1.1.0->autogluon.tabular) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->autogluon.core==1.1.0->autogluon.tabular) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->autogluon.core==1.1.0->autogluon.tabular) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->autogluon.core==1.1.0->autogluon.tabular) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->autogluon.core==1.1.0->autogluon.tabular) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.1.0->autogluon.tabular) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.1.0->autogluon.tabular) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.1.0->autogluon.tabular) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.1.0->autogluon.tabular) (2024.2.2)
# Installing collected packages: jmespath, scikit-learn, botocore, s3transfer, boto3, autogluon.common, autogluon.features, autogluon.core, autogluon.tabular
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed autogluon.common-1.1.0 autogluon.core-1.1.0 autogluon.features-1.1.0 autogluon.tabular-1.1.0 boto3-1.34.117 botocore-1.34.117 jmespath-1.0.1 s3transfer-0.10.1 scikit-learn-1.4.0

# %%
train_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/train.csv')
train_data
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       25            Private  178478   Bachelors             13
# 1       23          State-gov   61743     5th-6th              3
# 2       46            Private  376789     HS-grad              9
# 3       55                  ?  200235     HS-grad              9
# 4       36            Private  224541     7th-8th              4
# ...    ...                ...     ...         ...            ...
# 39068   54            Private   83103   Bachelors             13
# 39069   23            Private  172232     HS-grad              9
# 39070   37          Local-gov  165883     HS-grad              9
# 39071   26   Self-emp-not-inc   67240     HS-grad              9
# 39072   37          State-gov  210452     Masters             14
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Tech-support       Own-child   White
# 1            Never-married    Transport-moving   Not-in-family   White
# 2            Never-married       Other-service   Not-in-family   White
# 3       Married-civ-spouse                   ?         Husband   White
# 4       Married-civ-spouse   Handlers-cleaners         Husband   White
# ...                    ...                 ...             ...     ...
# 39068   Married-civ-spouse               Sales         Husband   White
# 39069        Never-married     Farming-fishing   Not-in-family   White
# 39070   Married-civ-spouse   Handlers-cleaners         Husband   Black
# 39071        Never-married   Handlers-cleaners   Not-in-family   White
# 39072   Married-civ-spouse     Exec-managerial         Husband   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0       Female             0             0              40   United-States
# 1         Male             0             0              35   United-States
# 2         Male             0             0              15   United-States
# 3         Male             0             0              50   United-States
# 4         Male             0             0              40     El-Salvador
# ...        ...           ...           ...             ...             ...
# 39068     Male             0             0              67   United-States
# 39069     Male             0             0              53   United-States
# 39070     Male             0             0              40   United-States
# 39071     Male             0             0              35   United-States
# 39072     Male             0             0              38   United-States
#
#         class
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3        >50K
# 4       <=50K
# ...       ...
# 39068   <=50K
# 39069   <=50K
# 39070   <=50K
# 39071   <=50K
# 39072   <=50K
#
# [39073 rows x 15 columns]

# %%
subsample_size = 500  # subsample subset of data for faster demo, try setting this to much larger values
train_data = train_data.sample(n=subsample_size, random_state=0)
train_data.head()
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 6118    51   Private   39264   Some-college             10
# 23204   58   Private   51662           10th              6
# 29590   40   Private  326310   Some-college             10
# 18116   37   Private  222450        HS-grad              9
# 33964   62   Private  109190      Bachelors             13
#
#             marital-status        occupation    relationship    race      sex  \
# 6118    Married-civ-spouse   Exec-managerial            Wife   White   Female
# 23204   Married-civ-spouse     Other-service            Wife   White   Female
# 29590   Married-civ-spouse      Craft-repair         Husband   White     Male
# 18116        Never-married             Sales   Not-in-family   White     Male
# 33964   Married-civ-spouse   Exec-managerial         Husband   White     Male
#
#        capital-gain  capital-loss  hours-per-week  native-country   class
# 6118              0             0              40   United-States    >50K
# 23204             0             0               8   United-States   <=50K
# 29590             0             0              44   United-States   <=50K
# 18116             0          2339              40     El-Salvador   <=50K
# 33964         15024             0              40   United-States    >50K

# %%
label = 'class'
print(f"Unique classes: {list(train_data[label].unique())}")
# Out:
# Unique classes: [' >50K', ' <=50K']

# %%
predictor = TabularPredictor(label=label).fit(train_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240603_120228"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20240603_120228"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Sun Apr 28 14:29:16 UTC 2024
# CPU Count:          2
# Memory Avail:       11.40 GB / 12.67 GB (90.0%)
# Disk Space Avail:   198.51 GB / 225.83 GB (87.9%)
# ===================================================
# Train Data Rows:    500
# Train Data Columns: 14
# Label Column:       class
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11676.51 MB
# 	Train Data (Original)  Memory Usage: 0.28 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])       : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('int', ['bool']) : 1 | ['sex']
# 	0.3s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.43s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 400, Val Rows: 100
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.73	 = Validation score   (accuracy)
# 	6.75s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.65	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.83	 = Validation score   (accuracy)
# 	3.8s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.85	 = Validation score   (accuracy)
# 	0.42s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.84	 = Validation score   (accuracy)
# 	1.19s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.83	 = Validation score   (accuracy)
# 	1.16s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost ...
# 	Warning: Exception caused CatBoost to fail during training (ImportError)... Skipping this model.
#
# Fitting model: ExtraTreesGini ...
# 	0.82	 = Validation score   (accuracy)
# 	1.21s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.81	 = Validation score   (accuracy)
# 	1.23s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.84	 = Validation score   (accuracy)
# 	2.4s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.86	 = Validation score   (accuracy)
# 	1.59s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.83	 = Validation score   (accuracy)
# 	7.13s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.83	 = Validation score   (accuracy)
# 	0.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'XGBoost': 1.0}
# 	0.86	 = Validation score   (accuracy)
# 	0.17s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 29.39s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240603_120228")

# %%
test_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv')
test_data.head()
# Out:
# Loaded data from: https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv | Columns = 15 / 15 | Rows = 9769 -> 9769
#    age          workclass  fnlwgt      education  education-num  \
# 0   31            Private  169085           11th              7
# 1   17   Self-emp-not-inc  226203           12th              8
# 2   47            Private   54260      Assoc-voc             11
# 3   21            Private  176262   Some-college             10
# 4   17            Private  241185           12th              8
#
#         marital-status        occupation relationship    race      sex  \
# 0   Married-civ-spouse             Sales         Wife   White   Female
# 1        Never-married             Sales    Own-child   White     Male
# 2   Married-civ-spouse   Exec-managerial      Husband   White     Male
# 3        Never-married   Exec-managerial    Own-child   White   Female
# 4        Never-married    Prof-specialty    Own-child   White     Male
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# 0             0             0              20   United-States   <=50K
# 1             0             0              45   United-States   <=50K
# 2             0          1887              60   United-States    >50K
# 3             0             0              30   United-States   <=50K
# 4             0             0              20   United-States   <=50K

# %%
y_pred = predictor.predict(test_data)
y_pred.head()  # Predictions
# Out:
# 0     <=50K
# 1     <=50K
# 2      >50K
# 3     <=50K
# 4     <=50K
# Name: class, dtype: object

# %%
y_pred_proba = predictor.predict_proba(test_data)
y_pred_proba.head()  # Prediction Probabilities
# Out:
#       <=50K      >50K
# 0  0.981126  0.018874
# 1  0.983599  0.016401
# 2  0.478133  0.521867
# 3  0.994751  0.005249
# 4  0.988539  0.011461

# %%
predictor.evaluate(test_data)
# Out:
# {'accuracy': 0.8409253761899887,
#  'balanced_accuracy': 0.7475663839529563,
#  'mcc': 0.5345297121913682,
#  'roc_auc': 0.884716037791454,
#  'f1': 0.6296472831267874,
#  'precision': 0.7034078807241747,
#  'recall': 0.5698878343399483}

# %%
predictor.leaderboard(test_data)
# Out:
#                   model  score_test  score_val eval_metric  pred_time_test  \
# 0      RandomForestGini    0.842870       0.84    accuracy        0.428740
# 1      RandomForestEntr    0.841130       0.83    accuracy        0.531994
# 2               XGBoost    0.840925       0.86    accuracy        0.139057
# 3   WeightedEnsemble_L2    0.840925       0.86    accuracy        0.142751
# 4              LightGBM    0.839799       0.85    accuracy        0.142799
# 5            LightGBMXT    0.836421       0.83    accuracy        0.071951
# 6        ExtraTreesEntr    0.833862       0.81    accuracy        0.417490
# 7        ExtraTreesGini    0.833862       0.82    accuracy        0.644015
# 8        NeuralNetTorch    0.833555       0.83    accuracy        0.138512
# 9         LightGBMLarge    0.828949       0.83    accuracy        0.106147
# 10      NeuralNetFastAI    0.828949       0.84    accuracy        0.391729
# 11       KNeighborsUnif    0.725970       0.73    accuracy        0.075016
# 12       KNeighborsDist    0.695158       0.65    accuracy        0.104176
#
#     pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0        0.084833  1.188522                 0.428740                0.084833
# 1        0.110643  1.156757                 0.531994                0.110643
# 2        0.030124  1.589947                 0.139057                0.030124
# 3        0.031056  1.760155                 0.003694                0.000932
# 4        0.010484  0.416959                 0.142799                0.010484
# 5        0.010597  3.800375                 0.071951                0.010597
# 6        0.090021  1.227254                 0.417490                0.090021
# 7        0.117749  1.214550                 0.644015                0.117749
# 8        0.015289  7.131579                 0.138512                0.015289
# 9        0.006895  0.450716                 0.106147                0.006895
# 10       0.037656  2.396566                 0.391729                0.037656
# 11       0.025720  6.748026                 0.075016                0.025720
# 12       0.034599  0.023112                 0.104176                0.034599
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            1.188522            1       True          5
# 1            1.156757            1       True          6
# 2            1.589947            1       True         10
# 3            0.170208            2       True         13
# 4            0.416959            1       True          4
# 5            3.800375            1       True          3
# 6            1.227254            1       True          8
# 7            1.214550            1       True          7
# 8            7.131579            1       True         11
# 9            0.450716            1       True         12
# 10           2.396566            1       True          9
# 11           6.748026            1       True          1
# 12           0.023112            1       True          2
